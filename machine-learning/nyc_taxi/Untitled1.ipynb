# %% [markdown]
# # PyCaret Machine Learning with Python

# %%
from pycaret.classification import * 
from pycaret.datasets import get_data

# %%
diabetes = get_data('diabetes')
exp_clf = setup(diabetes, target='Class variable')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %% [markdown]
# Finding the optimal algorithm
#
# Type the following:

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_2ec92 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# The **compare_models()** function gives you all that.
#
# It also highlights cells with the highest scores in yellow, so it’s easier to see.
#
# It look lige the **Ridge Classifier** (*ridge*) is the mest

# %%
rd = create_model('ridge')
# Out:
# <style type="text/css">
# #T_9b8ed_row10_col0, #T_9b8ed_row10_col1, #T_9b8ed_row10_col2, #T_9b8ed_row10_col3, #T_9b8ed_row10_col4, #T_9b8ed_row10_col5, #T_9b8ed_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9b8ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b8ed_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9b8ed_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9b8ed_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9b8ed_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9b8ed_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9b8ed_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9b8ed_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %% [markdown]
# Visualizing models performance

# %%
plot_model(rd)

# %%
plot_model(rd, 'confusion_matrix')

# %% [markdown]
# And the classification report:

# %%
plot_model(xgb, 'class_report')

# %% [markdown]
# Here’s the [link](https://pycaret.org/plot-model/) to all of the visualizations you can make.
#
# ## Model interpretation with SHAP
# SHAP, or SHapley Additive exPlanations, is a way to explain the outputs of a machine learning model. We can use it to see which features are most important by plotting the SHAP values of every feature for every sample.
#
# Once again, PyCaret makes it utterly simple to do:

# %%
interpret_model(rd)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [14], in <module>
# ----> 1 interpret_model(rd)
#
# File C:\Python310\lib\site-packages\pycaret\utils\generic.py:950, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     948     if globals_d[name] is None:
#     949         raise ValueError(message)
# --> 950 return func(*args, **kwargs)
#
# File C:\Python310\lib\site-packages\pycaret\classification\functional.py:1929, in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1830 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1831 def interpret_model(
#    1832     estimator,
#    (...)
#    1840     **kwargs,
#    1841 ):
#    1843     """
#    1844     This function takes a trained model object and returns an interpretation plot
# ...
